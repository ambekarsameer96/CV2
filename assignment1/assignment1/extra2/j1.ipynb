# %%
import os

# %%
path1 = './Data/data'

# %%
os.listdir('./')
# Out:
# ['CV2_assignment1_2022.pdf',
#  'Data',
#  'extra',
#  'j1.ipynb',
#  'main.py',
#  'main_sec3.py',
#  'Reading',
#  'README.txt',
#  'sampling_methods.py',
#  'SupplementalCode']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\ambek\\OneDrive - UvA\\Course_related\\period5\\CV2\\assignment\\github\\CV2\\assignment1\\assignment1'

# %%
files1 = os.listdir(path1)
l1 = []
for file1 in files1:
    if '.pcd' in str(file1):
        if not 'normal' in str(file1):
            print('\n')
            print(file1)
            file1 = os.path.join(path1, file1)
            l1.append(file1)
# Out:
# 0000000000.pcd
#
#
# 0000000001.pcd
#
#
# 0000000002.pcd
#
#
# 0000000003.pcd
#
#
# 0000000004.pcd
#
#
# 0000000005.pcd
#
#
# 0000000006.pcd
#
#
# 0000000007.pcd
#
#
# 0000000008.pcd
#
#
# 0000000009.pcd
#
#
# 0000000010.pcd
#
#
# 0000000011.pcd
#
#
# 0000000012.pcd
#
#
# 0000000013.pcd
#
#
# 0000000014.pcd
#
#
# 0000000015.pcd
#
#
# 0000000016.pcd
#
#
# 0000000017.pcd
#
#
# 0000000018.pcd
#
#
# 0000000019.pcd
#
#
# 0000000020.pcd
#
#
# 0000000021.pcd
#
#
# 0000000022.pcd
#
#
# 0000000023.pcd
#
#
# 0000000024.pcd
#
#
# 0000000025.pcd
#
#
# 0000000026.pcd
#
#
# 0000000027.pcd
#
#
# 0000000028.pcd
#
#
# 0000000029.pcd
#
#
# 0000000030.pcd
#
#
# 0000000031.pcd
#
#
# 0000000032.pcd
#
#
# 0000000033.pcd
#
#
# 0000000034.pcd
#
#
# 0000000035.pcd
#
#
# 0000000036.pcd
#
#
# 0000000037.pcd
#
#
# 0000000038.pcd
#
#
# 0000000039.pcd
#
#
# 0000000040.pcd
#
#
# 0000000041.pcd
#
#
# 0000000042.pcd
#
#
# 0000000043.pcd
#
#
# 0000000044.pcd
#
#
# 0000000045.pcd
#
#
# 0000000046.pcd
#
#
# ...

# %%
l1[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22452/2557072669.py in <module>
# ----> 1 l1[1]
#
# NameError: name 'l1' is not defined
